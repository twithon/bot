# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import random
import string
from sklearn.model_selection import KFold

# %%
df = pd.read_csv('dataset/tweetlabels1000_labeled.xlsx - Sheet2.csv')
print(df.shape)
df
# Out:
# (1003, 4)
#         No               Label     Username  \
# 0        0                none   chyrisalys
# 1        1  indirect complaint      woiidal
# 2        2              remark      ranieaw
# 3        3     negative remark      daeguv_
# 4        4  indirect complaint    fiorincha
# ...    ...                 ...          ...
# 998    998            campaign   sangwarior
# 999    999            campaign   sangwarior
# 1000  1000     negative remark    untextend
# 1001  1001            campaign   sangwarior
# 1002  1002             inquiry  narshashila
#
#                                                   Tweet
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   INDIHOME NGAPASIIII
# ...                                                 ...
# 998   Bisa sharing bareng sobat indihome gini kan as...
# 999   Sekarang nyantai dulu bentar sambil scroll sos...
# 1000  @JefriHandri Sini indihome down dr semalem jam...
# 1001  Ini barusan slesei sob... Lumayan buat nyari k...
# 1002          @IndiHomeCare daftar indihome lewat mana?
#
# [1003 rows x 4 columns]

# %%
# drop rows with label = campaign, own tweet, & incomplete
df = df.loc[~df['Label'].isin(['campaign','own tweet','incomplete'])].copy()
df
# Out:
#         No               Label       Username  \
# 0        0                none     chyrisalys
# 1        1  indirect complaint        woiidal
# 2        2              remark        ranieaw
# 3        3     negative remark        daeguv_
# 4        4  indirect complaint      fiorincha
# ...    ...                 ...            ...
# 994    994             inquiry   pecintamochi
# 995    995             inquiry  tetehaisyah51
# 997    997    direct complaint      untextend
# 1000  1000     negative remark      untextend
# 1002  1002             inquiry    narshashila
#
#                                                   Tweet
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   INDIHOME NGAPASIIII
# ...                                                 ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...
# 1000  @JefriHandri Sini indihome down dr semalem jam...
# 1002          @IndiHomeCare daftar indihome lewat mana?
#
# [722 rows x 4 columns]

# %%
# Label Encoding & drop columns
df['label'] = df['Label'].map({'indirect complaint': 0, 'remark': 1, 'negative remark': 2, 'direct compliment' : 3 , 'direct complaint' : 4, 'none' : 5, 'inquiry' : 6})
df.drop(['No', 'Label', 'Username'], axis=1, inplace=True)
df
# Out:
#                                                   Tweet  label
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
# [722 rows x 2 columns]

# %%
df.groupby( by='label').count()
# Out:
#        Tweet
# label
# 0         68
# 1        153
# 2        128
# 3         64
# 4        110
# 5        123
# 6         76

# %%
# to lowercase
df['tweet_lower'] = df['Tweet'].str.lower()
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
# [722 rows x 3 columns]

# %%
def text_cleansing(text):
    
       
    # remove non ASCII (emoticon, chinese word, etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    
    # remove digits (using regex) -> subtitute
    text = re.sub('\d+', '', text)
    
    # remove punctuation, reference: https://stackoverflow.com/a/34294398
    #text = text.translate(str.maketrans('', '', string.punctuation))
    
    # remove punctuation, except mention tag @
    text = re.sub(r'[^\w\s@]', '', text)
    
    # remove whitespace in the beginning and end of sentence
    text = text.strip()
    
    # remove extra whitespace in the middle of sentence (using regex)
    text = re.sub('\s+', ' ', text)
    
    # remove url in tweet (using regex)
    text = re.sub(r"\bhttp\w+", "", text)
    
    return text

# %%
# text_cleansing()
df['tweet_clean'] = df['tweet_lower'].apply(lambda x: text_cleansing(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean
# 0                            wifi watcha pasti indihome
# 1                           indihome ada masalah apasih
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3          indihome plis untuk tanggal jangan kesurupan
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min kalo jatuh tempo pembayaran ...
# 995   @indihomecare min indihome tv bisa gak berlang...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002           @indihomecare daftar indihome lewat mana
#
# [722 rows x 4 columns]

# %%
# normalization indonesian words
normalized_word = pd.read_csv('dataset/new_kamusalay.csv', header=None)
data_dict = dict(zip(normalized_word[0], normalized_word[1]))
len(data_dict)
# Out:
# 15166

# %%
def normalize_text(text):
    return ' '.join(data_dict.get(word, word) for word in text.split())

# %%
df['tweet_normalized'] = df['tweet_clean'].apply(lambda x: normalize_text(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean  \
# 0                            wifi watcha pasti indihome
# 1                           indihome ada masalah apasih
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3          indihome plis untuk tanggal jangan kesurupan
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min kalo jatuh tempo pembayaran ...
# 995   @indihomecare min indihome tv bisa gak berlang...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002           @indihomecare daftar indihome lewat mana
#
#                                        tweet_normalized
# 0                            wifi watcha pasti indihome
# 1                          indihome ada masalah apa sih
# 2     sore sore hujan rebahan bareng bocah cilik men...
# 3        indihome tolong untuk tanggal jangan kesurupan
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min kalau jatuh tempo pembayaran...
# 995   @indihomecare min indihome televisi bisa tidak...
# 997   @indihomecare @fauzindrianto dari semalam down...
# 1000  @jefrihandri sini indihome down dari semalam j...
# 1002           @indihomecare daftar indihome lewat mana
#
# [722 rows x 5 columns]

# %%
# stemming 'kata berimbuhan'
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
df['tweet_stemmed'] = df['tweet_normalized'].apply(lambda x: stemmer.stem(x))
df
# Out:
#                                                   Tweet  label  \
# 0                            wifi watcha pasti indihome      5
# 1                       indihome ada masalah apasih??!!      0
# 2     sore sore hujan rebahan bareng bocil nonton nu...      1
# 3     indihome plis untuk tanggal 10,13 jangan kesur...      2
# 4                                   INDIHOME NGAPASIIII      0
# ...                                                 ...    ...
# 994   @IndiHomeCare Min, kalo jatuh tempo pembayaran...      6
# 995   @IndiHomeCare Min, 1 IndiHome TV bisa gak berl...      6
# 997   @IndiHomeCare @fauzindrianto Dari semalem down...      4
# 1000  @JefriHandri Sini indihome down dr semalem jam...      2
# 1002          @IndiHomeCare daftar indihome lewat mana?      6
#
#                                             tweet_lower  \
# 0                            wifi watcha pasti indihome
# 1                       indihome ada masalah apasih??!!
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3     indihome plis untuk tanggal 10,13 jangan kesur...
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min, kalo jatuh tempo pembayaran...
# 995   @indihomecare min, 1 indihome tv bisa gak berl...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002          @indihomecare daftar indihome lewat mana?
#
#                                             tweet_clean  \
# 0                            wifi watcha pasti indihome
# 1                           indihome ada masalah apasih
# 2     sore sore hujan rebahan bareng bocil nonton nu...
# 3          indihome plis untuk tanggal jangan kesurupan
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min kalo jatuh tempo pembayaran ...
# 995   @indihomecare min indihome tv bisa gak berlang...
# 997   @indihomecare @fauzindrianto dari semalem down...
# 1000  @jefrihandri sini indihome down dr semalem jam...
# 1002           @indihomecare daftar indihome lewat mana
#
#                                        tweet_normalized  \
# 0                            wifi watcha pasti indihome
# 1                          indihome ada masalah apa sih
# 2     sore sore hujan rebahan bareng bocah cilik men...
# 3        indihome tolong untuk tanggal jangan kesurupan
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   @indihomecare min kalau jatuh tempo pembayaran...
# 995   @indihomecare min indihome televisi bisa tidak...
# 997   @indihomecare @fauzindrianto dari semalam down...
# 1000  @jefrihandri sini indihome down dari semalam j...
# 1002           @indihomecare daftar indihome lewat mana
#
#                                           tweet_stemmed
# 0                            wifi watcha pasti indihome
# 1                          indihome ada masalah apa sih
# 2     sore sore hujan rebah bareng bocah cilik tonto...
# 3            indihome tolong untuk tanggal jangan surup
# 4                                   indihome ngapasiiii
# ...                                                 ...
# 994   indihomecare min kalau jatuh tempo bayar indih...
# 995   indihomecare min indihome televisi bisa tidak ...
# 997   indihomecare fauzindrianto dari malam down tid...
# 1000  jefrihandri sini indihome down dari malam jam ...
# 1002            indihomecare daftar indihome lewat mana
#
# [722 rows x 6 columns]

# %%
# Define a function to compute the max length of sequence
def max_length(sequences):
    '''
    input:
        sequences: a 2D list of integer sequences
    output:
        max_length: the max length of the sequences
    '''
    max_length = 0
    for i, seq in enumerate(sequences):
        length = len(seq)
        if max_length < length:
            max_length = length
    return max_length

# %%
from tensorflow.keras import regularizers
from tensorflow.keras.constraints import MaxNorm

def define_model(input_dim = None, output_dim=300, max_length = None ):
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Embedding(input_dim=input_dim, 
                                  mask_zero= True,
                                  output_dim=output_dim, 
                                  input_length=max_length, 
                                  input_shape=(max_length, )),
        tf.keras.layers.Bidirectional(tf.keras.layers.GRU(64, return_sequences=True)),
        tf.keras.layers.Bidirectional(tf.keras.layers.GRU(64, return_sequences=False)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(units=7, activation='sigmoid')
    ])
    
    model.compile( loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
class myCallback(tf.keras.callbacks.Callback):
    # Overide the method on_epoch_end() for our benefit
    def on_epoch_end(self, epoch, logs={}):
        if (logs.get('accuracy') > 0.93):
            print("\nReached 93% accuracy so cancelling training!")
            self.model.stop_training=True


callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', min_delta=0, 
                                             patience=10, verbose=2, 
                                             mode='auto', restore_best_weights=True)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from keras.utils.np_utils import to_categorical

# Parameter Initialization
trunc_type='post'
padding_type='post'
oov_tok = "<UNK>"

columns = ['acc1', 'acc2', 'acc3', 'acc4', 'acc5', 'acc6', 'acc7', 'acc8', 'acc9', 'acc10', 'AVG']
record = pd.DataFrame(columns = columns)

# prepare cross validation with 10 splits and shuffle = True
kfold = KFold(n_splits=10, shuffle=False, random_state=None)

# Separate the tweet and label
tweets, labels = list(df.tweet_stemmed), list(df.label)

exp=0

# kfold.split() will return set indices for each split
acc_list = []
for train, test in kfold.split(tweets):
    
    exp+=1
    print('Training {}: '.format(exp))
    
    train_x, test_x = [], []
    train_y, test_y = [], []

    for i in train:
        train_x.append(tweets[i])
        train_y.append(labels[i])

    for i in test:
        test_x.append(tweets[i])
        test_y.append(labels[i])

    # Turn the labels into a numpy array
    train_y = np.array(train_y)
    test_y = np.array(test_y)
    
    # one-hot
    onehot_train_y = to_categorical(train_y)
    onehot_test_y = to_categorical(test_y)

    # encode data using Cleaning and Tokenization
    tokenizer = Tokenizer(oov_token=oov_tok)
    tokenizer.fit_on_texts(train_x)

    # Turn the text into sequence
    training_sequences = tokenizer.texts_to_sequences(train_x)
    test_sequences = tokenizer.texts_to_sequences(test_x)

    max_len = max_length(training_sequences)

    # Pad the sequence to have the same size
    Xtrain = pad_sequences(training_sequences, maxlen=max_len, padding=padding_type, truncating=trunc_type)
    Xtest = pad_sequences(test_sequences, maxlen=max_len, padding=padding_type, truncating=trunc_type)

    word_index = tokenizer.word_index
    vocab_size = len(word_index)+1

    # Define the input shape
    model = define_model(input_dim=vocab_size, max_length=max_len)

    # Train the model
    model.fit(Xtrain, onehot_train_y, batch_size=32, epochs=30, verbose=1, 
              callbacks=[callbacks], validation_data=(Xtest, onehot_test_y))

    # evaluate the model
    loss, acc = model.evaluate(Xtest, onehot_test_y, verbose=0)
    print('Test Accuracy: {}'.format(acc*100))

    acc_list.append(acc*100)

mean_acc = np.array(acc_list).mean()
entries = acc_list + [mean_acc]

temp = pd.DataFrame([entries], columns=columns)
record = record.append(temp, ignore_index=True)
print()
print(record)
print()
# Out:
# Training 1:
# Epoch 1/30
# 21/21 [==============================] - 15s 262ms/step - loss: 1.8975 - accuracy: 0.2696 - val_loss: 1.9817 - val_accuracy: 0.0959
# Epoch 2/30
# 21/21 [==============================] - 1s 70ms/step - loss: 1.6851 - accuracy: 0.3590 - val_loss: 1.8659 - val_accuracy: 0.2740
# Epoch 3/30
# 21/21 [==============================] - 1s 70ms/step - loss: 1.2363 - accuracy: 0.5593 - val_loss: 1.8007 - val_accuracy: 0.3288
# Epoch 4/30
# 21/21 [==============================] - 1s 69ms/step - loss: 0.7181 - accuracy: 0.7550 - val_loss: 2.0322 - val_accuracy: 0.2740
# Epoch 5/30
# 21/21 [==============================] - 1s 70ms/step - loss: 0.4080 - accuracy: 0.8706 - val_loss: 2.3002 - val_accuracy: 0.2603
# Epoch 6/30
# 21/21 [==============================] - 1s 68ms/step - loss: 0.2231 - accuracy: 0.9353 - val_loss: 2.6564 - val_accuracy: 0.2740
# Epoch 7/30
# 21/21 [==============================] - 2s 72ms/step - loss: 0.1500 - accuracy: 0.9630 - val_loss: 2.9069 - val_accuracy: 0.3014
# Epoch 8/30
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0906 - accuracy: 0.9707 - val_loss: 3.2131 - val_accuracy: 0.3014
# Epoch 9/30
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0662 - accuracy: 0.9846 - val_loss: 3.1488 - val_accuracy: 0.3425
# Epoch 10/30
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0880 - accuracy: 0.9723 - val_loss: 3.2388 - val_accuracy: 0.3151
# Epoch 11/30
# 21/21 [==============================] - 1s 72ms/step - loss: 0.0464 - accuracy: 0.9892 - val_loss: 3.2228 - val_accuracy: 0.3425
# Epoch 12/30
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0455 - accuracy: 0.9877 - val_loss: 3.6985 - val_accuracy: 0.3425
# Epoch 13/30
# 21/21 [==============================] - 1s 71ms/step - loss: 0.0470 - accuracy: 0.9892 - val_loss: 3.5264 - val_accuracy: 0.3562
# Epoch 14/30
# 21/21 [==============================] - 1s 68ms/step - loss: 0.0394 - accuracy: 0.9892 - val_loss: 3.6978 - val_accuracy: 0.3151
# Epoch 15/30
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0544 - accuracy: 0.9877 - val_loss: 3.5547 - val_accuracy: 0.3562
# Epoch 16/30
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0569 - accuracy: 0.9831 - val_loss: 3.8192 - val_accuracy: 0.3288
# Epoch 17/30
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0519 - accuracy: 0.9908 - val_loss: 3.8244 - val_accuracy: 0.2877
# Epoch 18/30
# 21/21 [==============================] - 1s 70ms/step - loss: 0.0284 - accuracy: 0.9938 - val_loss: 3.8224 - val_accuracy: 0.3151
# Epoch 19/30
# 21/21 [==============================] - 1s 68ms/step - loss: 0.0260 - accuracy: 0.9908 - val_loss: 3.9844 - val_accuracy: 0.3151
# Epoch 20/30
# 21/21 [==============================] - 1s 69ms/step - loss: 0.0262 - accuracy: 0.9908 - val_loss: 4.1975 - val_accuracy: 0.3014
# Epoch 21/30
# 21/21 [==============================] - 1s 68ms/step - loss: 0.
30
# 21/21 [==============================] - 3s 149ms/step - loss: 0.1770 - accuracy: 0.9462 - val_loss: 2.6375 - val_accuracy: 0.4167
# Epoch 8/30
# 21/21 [==============================] - 3s 149ms/step - loss: 0.1340 - accuracy: 0.9646 - val_loss: 2.7636 - val_accuracy: 0.4306
# Epoch 9/30
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0828 - accuracy: 0.9846 - val_loss: 2.8555 - val_accuracy: 0.3750
# Epoch 10/30
# 21/21 [==============================] - 3s 149ms/step - loss: 0.0608 - accuracy: 0.9831 - val_loss: 3.0147 - val_accuracy: 0.4444
# Epoch 11/30
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0683 - accuracy: 0.9862 - val_loss: 3.0614 - val_accuracy: 0.3750
# Epoch 12/30
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0441 - accuracy: 0.9908 - val_loss: 3.4375 - val_accuracy: 0.3611
# Epoch 13/30
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0389 - accuracy: 0.9908 - val_loss: 3.4051 - val_accuracy: 0.3889
# Epoch 14/30
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0404 - accuracy: 0.9908 - val_loss: 3.4108 - val_accuracy: 0.4167
# Epoch 15/30
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0436 - accuracy: 0.9877 - val_loss: 3.2412 - val_accuracy: 0.4444
# Epoch 16/30
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0329 - accuracy: 0.9923 - val_loss: 3.7262 - val_accuracy: 0.3750
# Epoch 17/30
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0352 - accuracy: 0.9908 - val_loss: 3.5702 - val_accuracy: 0.3750
# Epoch 18/30
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0313 - accuracy: 0.9923 - val_loss: 3.7885 - val_accuracy: 0.3750
# Epoch 19/30
# 21/21 [==============================] - 3s 150ms/step - loss: 0.0294 - accuracy: 0.9862 - val_loss: 3.6630 - val_accuracy: 0.3889
# Epoch 20/30
# 21/21 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9908Restoring model weights from the end of the best epoch: 10.
# 21/21 [==============================] - 3s 148ms/step - loss: 0.0319 - accuracy: 0.9908 - val_loss: 3.7072 - val_accuracy: 0.3889
# Epoch 20: early stopping
# Test Accuracy: 44.44444477558136
#
#        acc1       acc2  acc3       acc4       acc5      acc6      acc7  \
# 0  35.61644  41.095892  50.0  43.055555  44.444445  48.61111  51.38889
#
#         acc8       acc9      acc10        AVG
# 0  56.944442  34.722221  44.444445  45.032344
# C:\Users\baktistr\AppData\Local\Temp\ipykernel_66428\3147406012.py:82: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   record = record.append(temp, ignore_index=True)

# %%
record
# Out:
#        acc1       acc2  acc3       acc4       acc5      acc6      acc7  \
# 0  35.61644  41.095892  50.0  43.055555  44.444445  48.61111  51.38889
#
#         acc8       acc9      acc10        AVG
# 0  56.944442  34.722221  44.444445  45.032344

# %%
# define the preprocessing pipeline
def text_preprocessing(text):
    # case folding
    text = text.lower()
    
    # text cleansing
    text = text_cleansing(text)
    
    # text normalization
    text = normalize_text(text)
    
    # stemming
    text = stemmer.stem(text)
    
    return text

# %%
from keras.utils.np_utils import to_categorical

# unseen tweet
new_tweet = "@IndiHome internet saya lemot sudah 3 hari"

# preprocess
text_cleaned = text_preprocessing(new_tweet)
text_sequence = tokenizer.texts_to_sequences([text_cleaned])

max_len= max_length(training_sequences)

seq_padded = pad_sequences(text_sequence, maxlen=max_len, padding=padding_type, truncating=trunc_type)

# prediction
pred_proba = model.predict(seq_padded)

result = np.argmax(pred_proba)
result = {
    0: lambda result: "indirect complaint",
    1: lambda result: "remark",
    2: lambda result: "negative remark",
    3: lambda result: "direct compliment",
    4: lambda result: "direct complaint",
    5: lambda result: "none",
    6: lambda result: "inquiry"
}[result](result)

print(result)
# Out:
# direct complaint
